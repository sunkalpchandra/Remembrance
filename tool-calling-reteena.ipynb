# %%
from langchain_core.tools import tool

@tool
def weatherAndTimeIn(a: str) -> str:
    """figure out the weather and time in city a.

    Args:
        a: city name str
       
    """
    querystring = {"q": a}

    headers = {
        "x-rapidapi-host": "weatherapi-com.p.rapidapi.com",
        "x-rapidapi-key": "ba3402778bmsha1454397da615e2p185bbbjsna87890bf57c6"  # Replace with your actual API key
    }
    
    response = requests.get(url, headers=headers, params=querystring)
    
    return response.json()

# %%
import requests

url = "https://weatherapi-com.p.rapidapi.com/alerts.json"
  # Print the response in JSON format

# %%
endpoint = "https://hub8636750531.openai.azure.com/"

# %%
# !pip install -qU "langchain[openai]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.4/423.4 kB 8.0 MB/s eta 0:00:00ta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 kB 33.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.

# %%
import getpass
import os

if not os.environ.get("AZURE_OPENAI_API_KEY"):
  os.environ["AZURE_OPENAI_API_KEY"] = key

from langchain_openai import AzureChatOpenAI

model = AzureChatOpenAI(
    azure_endpoint=endpoint,
    #azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version="2024-10-01-preview",
)

# %%
model_with_tools = llm.bind_tools([weatherAndTimeIn])

# %%
result = model_with_tools.invoke("tell me the weather and time in london")
print(result)
# Out:
# content='' additional_kwargs={'tool_calls': [{'id': 'call_D07nz4hpQfD2FFTIO57RN3yq', 'function': {'arguments': '{"a":"London"}', 'name': 'weatherAndTimeIn'}, 'type': 'function'}], 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 65, 'total_tokens': 82, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ded0d14823', 'id': 'chatcmpl-BI6w6xXPNvyQWybMODThxado1oX1C', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 
# ...

# %%
tools = {"weatherandtimein": weatherAndTimeIn}  # Ensure the key matches the expected lowercase tool name

for tool_call in result.tool_calls:
    tool_name = tool_call["name"].lower()  # Convert to lowercase for consistency
    selected_tool = tools.get(tool_name)  # Use .get() to avoid KeyError

    if selected_tool:
        tool_msg = selected_tool.invoke(tool_call)
        messages.append(tool_msg)
    else:
        print(f"Warning: No matching tool found for {tool_name}")

print(messages)
# Out:
# [('system', 'You are a helpful assistant'), ('human', 'I love programming.'), ToolMessage(content='{"error": {"code": 1006, "message": "No matching location found."}}', name='weatherAndTimeIn', tool_call_id='call_Wxlrhtmsw9e4q40B3SCP3THE'), ToolMessage(content='{"location": {"name": "London", "region": "City of London, Greater London", "country": "United Kingdom", "lat": 51.5171, "lon": -0.1062, "tz_id": "Europe/London", "localtime_epoch": 1743656141, "localtime": "2025-04-03 05:55"}, "alerts": {"alert": []}}', name='weatherAndTimeIn', tool_call_id='call_D07nz4hpQfD2FFTIO57RN3yq')]

# %%
from langchain_openai import AzureChatOpenAI

llm = AzureChatOpenAI(
    azure_endpoint="https://hub8636750531.openai.azure.com/",
    openai_api_key="5iniaVJJEZw4w2JDig0KnE1tLXIIi5exBhaokz1w0x4mfsV46XU8JQQJ99BCACHYHv6XJ3w3AAAAACOG66gm",
    api_version="2025-02-01-preview",
    deployment_name="gpt-4o-mini", 
)

messages = [
    (
        "system",
        "You are a helpful assistant",
    ),
    ("human", "I love programming."),
]
response = llm.invoke(messages)

print(response)
# Out:
# content="That's great to hear! Programming is a powerful skill that allows you to create and solve problems in various ways. What languages or frameworks are you interested in, or do you have a specific project you're working on?" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 20, 'total_tokens': 63, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ded0d14823', 'id': 'chatcmpl-BI6qe2WbLNmwJeAcDz7LNeZ18eDke', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'fil
# ...

# %%
import requests

url = "https://weatherapi-com.p.rapidapi.com/alerts.json"
querystring = {"q": "london"}

headers = {
    "x-rapidapi-host": "weatherapi-com.p.rapidapi.com",
    "x-rapidapi-key": "ba3402778bmsha1454397da615e2p185bbbjsna87890bf57c6"  # Replace with your actual API key
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())  # Print the response in JSON format
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.5171, 'lon': -0.1062, 'tz_id': 'Europe/London', 'localtime_epoch': 1743655701, 'localtime': '2025-04-03 05:48'}, 'alerts': {'alert': []}}
